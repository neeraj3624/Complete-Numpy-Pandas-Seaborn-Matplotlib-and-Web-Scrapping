# %%
import seaborn as sns
import pandas as pd
import numpy as  np

import matplotlib as plt

# %%
data=sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(data=data,x="day",y="sex",estimator='sex')
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.barplot(data=data,x="day",y="sex",estimator='sex')
#       2 plt.plot()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
# ...

# %%
sns.histplot(data,x='day',hue='sex',kde=True,discrete=True,bins=5)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(data,markers="*")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2556\1330160432.py:1: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data,markers="*")
# <Axes: >
