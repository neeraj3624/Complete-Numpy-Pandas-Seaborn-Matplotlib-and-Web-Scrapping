# %%
import matplotlib.pyplot as plt

# %%
import numpy as np 
import pandas as pd

# %%
data=np.array([1,13,3,45,3,5,654,634,33])
plt.stem(data,orientation="horizontal")
plt.show()

# %%
plt.hist(data,color="red")
# Out:
# (array([7., 0., 0., 0., 0., 0., 0., 0., 0., 2.]),
#  array([  1. ,  66.3, 131.6, 196.9, 262.2, 327.5, 392.8, 458.1, 523.4,
#         588.7, 654. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.violinplot(data,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x1551e360190>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1551e3602d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1551e360410>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1551e360550>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x1551e360690>}

# %%
n1=[1,2,3,4,45,66,3,77]
n2=[32,4,5,35,5,463,432,534]
plt.stackplot(n1,n2)
plt.savefig('grap1.png')

# %%
import seaborn as sns
import pandas as pd

# %%
data={"Days":[1,2,3,4,5],
      "NOP":[60,70,80,30,7]
}
df=pd.DataFrame(data)
print(df)
sns.lineplot(df,x="Days",y="NOP")
# Out:
#    Days  NOP
# 0     1   60
# 1     2   70
# 2     3   80
# 3     4   30
# 4     5    7
# <Axes: xlabel='Days', ylabel='NOP'>

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("Merge_Append_PowerBI_Data.xlsx")

# %%
data.head()
# Out:
#    CustomerID CustomerName Region SignupDate
# 0           1   Customer_1   East 2021-05-16
# 1           2   Customer_2   West 2022-08-16
# 2           3   Customer_3  North 2023-03-14
# 3           4   Customer_4   East 2023-05-09
# 4           5   Customer_5   East 2022-07-17

# %%
sns.lineplot(data,x="CustomerName",y="Region")
sns.color_palette("viridis")
# Out:
# [(0.275191, 0.194905, 0.496005),
#  (0.212395, 0.359683, 0.55171),
#  (0.153364, 0.497, 0.557724),
#  (0.122312, 0.633153, 0.530398),
#  (0.288921, 0.758394, 0.428426),
#  (0.626579, 0.854645, 0.223353)]

# %%
sns.barplot(data['CustomerID'])
# Out:
# <Axes: ylabel='CustomerID'>
