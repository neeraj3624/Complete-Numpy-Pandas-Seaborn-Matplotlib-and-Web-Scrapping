# %%
print(df.isnull().sum())
print(df["row_name"].duplicated().sum())

data.drop_duplicates("row_name")

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Merge_Append_PowerBI_Data.xlsx")
df
# Out:
#      CustomerID   CustomerName Region SignupDate
# 0             1     Customer_1   East 2021-05-16
# 1             2     Customer_2   West 2022-08-16
# 2             3     Customer_3  North 2023-03-14
# 3             4     Customer_4   East 2023-05-09
# 4             5     Customer_5   East 2022-07-17
# ..          ...            ...    ...        ...
# 995         996   Customer_996  North 2023-02-10
# 996         997   Customer_997  North 2023-06-10
# 997         998   Customer_998   West 2020-01-17
# 998         999   Customer_999   West 2020-12-25
# 999        1000  Customer_1000   East 2023-05-31
#
# [1000 rows x 4 columns]

# %%
df.head()
# Out:
#    CustomerID CustomerName Region SignupDate
# 0           1   Customer_1   East 2021-05-16
# 1           2   Customer_2   West 2022-08-16
# 2           3   Customer_3  North 2023-03-14
# 3           4   Customer_4   East 2023-05-09
# 4           5   Customer_5   East 2022-07-17

# %%
df.describe()
# Out:
#         CustomerID                     SignupDate
# count  1000.000000                           1000
# mean    500.500000  2022-01-16 21:50:23.999999744
# min       1.000000            2020-01-01 00:00:00
# 25%     250.750000            2020-12-21 00:00:00
# 50%     500.500000            2022-02-06 00:00:00
# 75%     750.250000            2023-02-10 00:00:00
# max    1000.000000            2024-02-08 00:00:00
# std     288.819436                            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1000 non-null   int64
#  1   CustomerName  1000 non-null   object
#  2   Region        1000 non-null   object
#  3   SignupDate    1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 31.4+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID      0
# CustomerName    0
# Region          0
# SignupDate      0
# dtype: int64

# %%
df.tail()
# Out:
#      CustomerID   CustomerName Region SignupDate
# 995         996   Customer_996  North 2023-02-10
# 996         997   Customer_997  North 2023-06-10
# 997         998   Customer_998   West 2020-01-17
# 998         999   Customer_999   West 2020-12-25
# 999        1000  Customer_1000   East 2023-05-31

# %%
df.dropna()
# Out:
#      CustomerID   CustomerName Region SignupDate
# 0             1     Customer_1   East 2021-05-16
# 1             2     Customer_2   West 2022-08-16
# 2             3     Customer_3  North 2023-03-14
# 3             4     Customer_4   East 2023-05-09
# 4             5     Customer_5   East 2022-07-17
# ..          ...            ...    ...        ...
# 995         996   Customer_996  North 2023-02-10
# 996         997   Customer_997  North 2023-06-10
# 997         998   Customer_998   West 2020-01-17
# 998         999   Customer_999   West 2020-12-25
# 999        1000  Customer_1000   East 2023-05-31
#
# [1000 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID      0
# CustomerName    0
# Region          0
# SignupDate      0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.replace(np.nan,"hi")
# Out:
#      CustomerID   CustomerName Region SignupDate
# 0             1     Customer_1   East 2021-05-16
# 1             2     Customer_2   West 2022-08-16
# 2             3     Customer_3  North 2023-03-14
# 3             4     Customer_4   East 2023-05-09
# 4             5     Customer_5   East 2022-07-17
# ..          ...            ...    ...        ...
# 995         996   Customer_996  North 2023-02-10
# 996         997   Customer_997  North 2023-06-10
# 997         998   Customer_998   West 2020-01-17
# 998         999   Customer_999   West 2020-12-25
# 999        1000  Customer_1000   East 2023-05-31
#
# [1000 rows x 4 columns]

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of      CustomerID   CustomerName Region SignupDate
# 0             1     Customer_1   East 2021-05-16
# 1             2     Customer_2   West 2022-08-16
# 2             3     Customer_3  North 2023-03-14
# 3             4     Customer_4   East 2023-05-09
# 4             5     Customer_5   East 2022-07-17
# ..          ...            ...    ...        ...
# 995         996   Customer_996  North 2023-02-10
# 996         997   Customer_997  North 2023-06-10
# 997         998   Customer_998   West 2020-01-17
# 998         999   Customer_999   West 2020-12-25
# 999        1000  Customer_1000   East 2023-05-31
#
# [1000 rows x 4 columns]>

# %%
df["CustomerID"]=df["CustomerID"].replace(np.nan,"hi")

# %%
df["CustomerID"].mean()
# Out:
# np.float64(500.5)

# %%
df["CustomerID"].median()
# Out:
# np.float64(500.5)

# %%
df.fillna(method="bfill")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25244\3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#      CustomerID   CustomerName Region SignupDate
# 0             1     Customer_1   East 2021-05-16
# 1             2     Customer_2   West 2022-08-16
# 2             3     Customer_3  North 2023-03-14
# 3             4     Customer_4   East 2023-05-09
# 4             5     Customer_5   East 2022-07-17
# ..          ...            ...    ...        ...
# 995         996   Customer_996  North 2023-02-10
# 996         997   Customer_997  North 2023-06-10
# 997         998   Customer_998   West 2020-01-17
# 998         999   Customer_999   West 2020-12-25
# 999        1000  Customer_1000   East 2023-05-31
#
# [1000 rows x 4 columns]

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25244\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#      CustomerID   CustomerName Region SignupDate
# 0             1     Customer_1   East 2021-05-16
# 1             2     Customer_2   West 2022-08-16
# 2             3     Customer_3  North 2023-03-14
# 3             4     Customer_4   East 2023-05-09
# 4             5     Customer_5   East 2022-07-17
# ..          ...            ...    ...        ...
# 995         996   Customer_996  North 2023-02-10
# 996         997   Customer_997  North 2023-06-10
# 997         998   Customer_998   West 2020-01-17
# 998         999   Customer_999   West 2020-12-25
# 999        1000  Customer_1000   East 2023-05-31
#
# [1000 rows x 4 columns]
